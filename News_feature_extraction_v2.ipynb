# %% [markdown]
# # **Installation and Import Packages**

# %%
# !pip install newspaper3k
# Out:
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.10/dist-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.11.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (9.4.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0.1)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.3)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.31.0)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0.10)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.4.4)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2023.7.22)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.12.2)

# %%
# !pip install word2number
# Out:
# Requirement already satisfied: word2number in /usr/local/lib/python3.10/dist-packages (1.1)

# %%
from newspaper import Article
import spacy
from spacy.matcher import Matcher
import pandas as pd
import spacy
from spacy import displacy
import re
from word2number import w2n
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk

# %%
nltk.download('punkt')
nlp = spacy.load('en_core_web_sm') # for ner
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # **Read BD location dictionary**

# %%
url = 'https://raw.githubusercontent.com/nurshatfateh/WebScraping-NaturalLanguageProcessing/main/dictionary.csv'
df = pd.read_csv(url,header=None)
df.head()
bd_dist_name = df.iloc[:,2].tolist()
bd_dist_name =list(set(bd_dist_name))  #remove duplicate name

# %% [markdown]
# # **Helper Function**

# %%
#Extract sentences from new article - look for sentence containig targe word list
def accident_related_sentences(text):
  target_words=['accident', 'die','collide','crash','kill','injure','wound','collision','plunge'] #--- can be changed/modified the list
  doc = nlp(text)
  result=[]
  for sentence in doc.sents:
        lemmatized_words = [token.lemma_.lower() for token in sentence]
        if any(lemma in lemmatized_words for lemma in target_words):
            result.append(sentence.text.lower())   # --- converted to lower case
  return result

# %%
# -- The funtion take accident related text and serh
def find_accident_loc(result, fulltext):
  accLocation=[]
  #location find by dictionary
  for sentence in result:
    words = word_tokenize(sentence) #[token.text for token in str(sentence)]
    for place in words:
      if place in bd_dist_name:
        accLocation.append(place)

    # location found by Name Entitiy recognition tag
  nerLoc=[]
  nerSentence= nlp(fulltext)
  for ner in nerSentence.ents:
    if(ner.label_=="GPE"):
      nerLoc.append(ner)

  return list(set(accLocation)), list(set(nerLoc))

# %%
# extract Age from text- required to as death/injur numbe funtion sometimes detect as target number.
# so in tht case age need to be removed from death/injure list
'''def find_age(text):
  age_=[]
  for sentence in text:
      age = re.findall(r'Age[\:\s](\d{1,3})', sentence)
      age.extend(re.findall(r' (\d{1,3}),? ', sentence))
      if len(age) == 0:
        age = re.findall(r'\((\d{1,3})\)', sentence)
      age_.append(age)
      ageList=[int(item) for sublist in age_ for item in sublist]
  return list(set(ageList))'''
# Out:
# "def find_age(text):\n  age_=[]\n  for sentence in text:\n      age = re.findall(r'Age[\\:\\s](\\d{1,3})', sentence)\n      age.extend(re.findall(r' (\\d{1,3}),? ', sentence))\n      if len(age) == 0:\n        age = re.findall(r'\\((\\d{1,3})\\)', sentence)\n      age_.append(age)\n      ageList=[int(item) for sublist in age_ for item in sublist]\n  return list(set(ageList))"

# %%
def removeAgeinfo(text):
    age_pattern = r'(\b(?:[A-Z][a-z]*\s*){1,3}),\s*(\d{1,3})\b'
    age_matches = re.findall(age_pattern, text)
    for name, age in age_matches:
      #print(f"Name: {name}, Age: {age}")
      text = re.sub(re.escape(f"{name}, {age}"), "", text)

    #print(text)
    return text

# %%
def find_death_injure_number(sentence):
  death_,injure_ = [],[]
  string= ""
  # print(sentence)
  for text in sentence:

    #covert all word number to numeric form
    numeric_word=[]
    text_num= nlp(text)
    for word in text_num.ents:
      if(word.label_=="CARDINAL"):
        if ' ' in word.text:
          templist= word.text.split();
          #print(templist)
          for w in templist:
            if(w.isnumeric()!=1):
              numeric_word.append(w)

        else:
          if(word.text.isnumeric()!=1):
            numeric_word.append(word.text)

    if len(numeric_word)>0:
      for numword in numeric_word:
        result= text.find(numword)              #give first index position
        prepart=text[:result]                   #split the 1st part of string before numeric word
        nextpart=text[result+len(numword):]     # split the last part of string after numeric word

        # convert numeric word to int number
        try:
          res = w2n.word_to_num(text[result:result+len(numword)])
        except Exception as e:
          continue
        string= prepart+str(res)+nextpart       # concate the separated string part
    else:
      string= text

    # find the closet number of the give word.
    wordList= ["kill","dead","die","injure","wound"]
    for keyword in wordList:
      expression1 = r"(?i)(?:\b"+keyword+"\D{0,20})([0-9][0-9,]*)[^.,]|([0-9][0-9,]*)[^.,](?:\D{0,20}"+keyword+")"
      expression2 = r"(?:(?<!\S)(\d+(?:,\d+)?)(?!\S)\D*\b"+keyword+"|\b"+keyword+"\D*(?<!\S)(\d+(?:,\d+)?)(?!\S))"
      res1= re.findall(expression1, string)
      res2= re.findall(expression2, string)
      output= [' '.join(temp) for temp in res1]+[''.join(temp) for temp in res2]

      res= list(set(output))
      if keyword != "injure" and keyword != "wound":
        death_.append(res)
      else:
        injure_.append(res)

    #clear duplicate and  death number matched with injure number
  #death=[float(s.replace(',', '')) for s in string_array]
  death=[float(item.replace(',', '')) for sublist in death_ for item in sublist]
  injure=[float(item.replace(',', '')) for sublist in injure_ for item in sublist]

  death=list(set(death))
  #print("death: ",death)
  injure=list(set(injure))
  #print("inj: ", injure)
  #death_final= [num for num in death if num not in injure]
  #print("final death: ",death_final)
  return death, injure

# %%
from datetime import datetime
from dateutil import parser

def convert24(str1):

    # Checking if last two elements of time
    # is AM and first two elements are 12
    if str1[-2:] == "AM" and str1[:2] == "12":
        return "00" + str1[2:-2]

    # remove the AM
    elif str1[-2:] == "AM":
        return str1[:-2]

    # Checking if last two elements of time
    # is PM and first two elements are 12
    elif str1[-2:] == "PM" and str1[:2] == "12":
        return str1[:-2]

    else:

        # add 12 to hours and remove PM
        return str(int(str1[:2]) + 12) + str1[2:8]


def find_time_of_accident(sentence):
    daypart=[]
    partoftheday=""
    formatted_time=""

    time12form=re.findall(r'\d?\d(?::\d\d)?\s*[ap]m', sentence)
    #print("time12-",time12form)
    doc = nlp(sentence)
    timelist=[]
    for word in doc.ents:
      if word.label_=="TIME":
        timelist.append(word.text)
    timelist= list(set(timelist+time12form))
   # print("time from ner-",timelist)
    for time in timelist:
      if any(char.isdigit() for char in time):
        try:
          parsed_time = parser.parse(time)
          if parsed_time.time():
            formatted_time = parsed_time.strftime("%I:%M %p")
        except ValueError:
          pass

      try:
        time24format= convert24(formatted_time)
        #print("converted-",time24format)
        #print(time24format)
        hr=int(time24format[:2])
        if hr>=5 and hr<12:
          partoftheday="Morning"
        elif hr>=12 and hr<18:
          partoftheday="Afternoon"
        elif hr>=18 and hr<20:
          partoftheday="Evening"
        elif hr>=20 and hr<=24 or hr>=0 and hr<5:
          partoftheday="Night"
        daypart.append(partoftheday)
      except ValueError:
          pass
    #print("daypart-", daypart)
    return list(set(time12form)), list(set(daypart))

# %%
def extract_vehicles(text):
    #  vehicle = ['truck','bus','car','bike','motorcycle','rickshaw','auto-rickshaw','tempo', 'pickup','train']
    vehicle_patterns = r"\b(?:bus|truck|car|motorbike|bike|rickshaw|cycle|bicycle|motorcycle|auto-rickshaw|tempo|pickup|train|honda)\b"
    extracted_vehicles = re.findall(vehicle_patterns, text, flags=re.IGNORECASE)
    return list(set(extracted_vehicles))

# %% [markdown]
# # **News Data Read**

# %%
news=pd.read_csv('newsarticles.csv')
news
# Out:
#      Unnamed: 0        date  \
# 0           179  2022-08-16
# 1           145  2022-08-29
# 2           182  2022-09-15
# 3           194  2022-10-03
# 4           175  2022-10-08
# ..          ...         ...
# 195          49  2023-07-28
# 196           4  2023-07-28
# 197           1  2023-07-28
# 198          40  2023-07-29
# 199           0  2023-07-29
#
#                                                   link  \
# 0    https://www.thedailystar.net/news/bangladesh/a...
# 1    https://www.dhakatribune.com/bangladesh/2022/0...
# 2    https://www.tbsnews.net/bangladesh/4-killed-10...
# 3    https://www.tbsnews.net/bangladesh/road-crashe...
# 4    https://www.newagebd.net/article/183133/11-peo...
# ..                                                 ...
# 195  https://www.thedailystar.net/business/economy/...
# 196  https://bangladeshpost.net/posts/motorcyclist-...
# 197  https://www.thedailystar.net/news/bangladesh/a...
# 198  https://www.daily-bangladesh.com/english/inter...
# 199  https://www.thedailystar.net/news/bangladesh/a...
#
#                                                  title
# 0                        5 lives lost to gross neglect
# 1         4 killed in road accidents across Bangladesh
# 2     4 killed, 10 injured in Chattogram road accident
# 3    Road crashes claim 476 lives in September: Report
# 4    11 people killed as bus catches fire after roa...
# ..                                                 ...
# 195  Vehicle insurance business going thru tough times
# 196      Motorcyclist killed in Satkhira road accident
# 197  Road Safety Movement 2018: Infrastructure impr...
# 198  6 killed, 20 injured as 2 buses collide in Ind...
# 199      Three bikers killed in Kurigram road accident
#
# [200 rows x 4 columns]

# %%
newsDate, accidentLocation, deathNumber, injuredNumber=[],[],[],[]
accTime, dayPart, vechileList, acciddentType=[],[],[],[]
newsUrl, newsText=[],[]

for i in range(len(news)): #range(len(news)):   #49 -test for age  # 13 te problem
  try:
    article = Article(news['link'][i])
    article.download()
    article.parse()


    print(i, "--", news['title'][i])
    newsText.append(article.text)   #add in a column
    newsDate.append(news['date'][i])  # add as column
    newsUrl.append(news['link'][i])

    textWithTitle= news['title'][i]+". "+ article.text #added title with the text
    clearText=removeAgeinfo(textWithTitle)
    related_text=accident_related_sentences(clearText) #to find location
    related_text

    AccicdentLoc, NERloc= find_accident_loc(related_text, textWithTitle)
    print("1. Location: ",AccicdentLoc)
    accidentLocation.append(AccicdentLoc)

    death_num, injure_num= find_death_injure_number(related_text)
    print("2. DeathNo: ",death_num)
    print("3. Injurred: ",injure_num)
    injuredNumber.append(injure_num)
    if len(death_num)==0:
      deathNumber.append(1)
    else:
      deathNumber.append(death_num)

    time, partOfDay= find_time_of_accident(article.text)
    print("4. Time: ",time)
    print("5. Daypart: ",partOfDay)
    accTime.append(time)
    dayPart.append(partOfDay)

    extracted_vehicles = extract_vehicles(article.text)
    print("6. Vehicle: ",extracted_vehicles)
    vechileList.append(extracted_vehicles)

    if len(extracted_vehicles)==0:
      print("7. AccidentType: N/A")
      acciddentType.append("N/A")
    elif len(extracted_vehicles)==1:
      print("7. AccidentType: vehicle-human")
      acciddentType.append("vehicle-human")
    else:
      print("7. AccidentType: vehicle-vehicle")
      acciddentType.append("vehicle-vehicle")
    print('\n')
  except Exception as e:
    continue
# Out:
# 0 -- 5 lives lost to gross neglect
# 1. Location:  ['uttara', 'islampur', 'dhaka', 'gazipur', 'jamalpur']
# 2. DeathNo:  [2.0, 12.0, 70.0, 15.0]
# 3. Injurred:  [3.0, 12.0]
# 4. Time:  ['4:00pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['Bus', 'bus', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 2 -- 4 killed, 10 injured in Chattogram road accident
# 1. Location:  ['palash', 'chattogram']
# 2. DeathNo:  [10.0, 4.0]
# 3. Injurred:  [10.0, 2.0]
# 4. Time:  ['1:30am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 4 -- 11 people killed as bus catches fire after road accident in India
# 1. Location:  []
# 2. DeathNo:  [11.0]
# 3. Injurred:  []
# 4. Time:  ['5:15am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 5 -- Beyond awareness: A new decade of action on road safety
# 1. Location:  []
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 6 -- Youth killed in Narail road accident - Dhaka
# 1. Location:  ['narail', 'dhaka', 'tularampur']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['8:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['car', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 7 -- 2 killed, 2 injured in Chuadanga road accident
# 1. Location:  ['chuadanga', 'alukdia']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['3:00am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 8 -- 2 killed, 2 injured in Chuadanga road accident
# 1. Location:  ['chuadanga', 'alukdia']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['3:00am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 9 -- Army member killed in Bogura road accident - Dhaka
# 1. Location:  ['bogura', 'dhaka', 'shahjahanpur']
# 2. DeathNo:  [3.0]
# 3. Injurred:  [3.0, 4.0]
# 4. Time:  ['8:30pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['auto-rickshaw', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 10 -- Compensation for road accident victims elusive
# 1. Location:  ['dhaka']
# 2. DeathNo:  [2018.0]
# 3. Injurred:  [2018.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 11 -- Compensation for road accident victims elusive
# 1. Location:  ['dhaka']
# 2. DeathNo:  [2018.0]
# 3. Injurred:  [2018.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 12 -- Woman dies as car hits and drags her a kilometre at Dhaka University
# 1. Location:  ['dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['3pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['motorcycle', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 14 -- Motorcyclist killed in Narayanganj road accident - Dhaka
# 1. Location:  ['mouchak', 'narayanganj', 'dhaka', 'noakhali']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['11:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 16 -- Road accidents kill 9,951 in 2022
# 1. Location:  ['dhaka', 'chattogram']
# 2. DeathNo:  [44.0, 550.0]
# 3. Injurred:  [201.0, 83.0, 357.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 17 -- Three killed in road accidents in Khulna, Magura
# 1. Location:  ['khulna', 'faridpur', 'sreepur', 'daulatpur', 'magura']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  []
# 4. Time:  ['9:00am', '11:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 18 -- Three killed in road accidents in Khulna, Magura
# 1. Location:  ['khulna', 'faridpur', 'sreepur', 'daulatpur', 'magura']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  []
# 4. Time:  ['9:00am', '11:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 19 -- Three killed in road accidents in Khulna, Magura
# 1. Location:  ['khulna', 'faridpur', 'sreepur', 'daulatpur', 'magura']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  []
# 4. Time:  ['9:00am', '11:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 20 -- Bangladesh govt frames rules for road safety law after 4 years
# 1. Location:  ['dhaka']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [1.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'bus', 'car', 'truck', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 21 -- 4 members of a family among 5 killed in Habiganj road crash
# 1. Location:  ['habiganj']
# 2. DeathNo:  [3.0, 5.0]
# 3. Injurred:  [3.0]
# 4. Time:  ['30am']
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 22 -- Tourist killed, seven injured in Cox's Bazar road accident
# 1. Location:  ['ramu']
# 2. DeathNo:  [1.0, 7.0]
# 3. Injurred:  [8.0, 7.0]
# 4. Time:  ['10pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 23 -- Road accidents eat up over 1.5pc of GDP
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['10:00pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['Bike', 'bike']
# 7. AccidentType: vehicle-vehicle
#
#
# 24 -- Roads must not remain death trap
# 1. Location:  ['kanchan', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  [10.0, 2.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 25 -- Five killed in road accidents in Rajshahi, Pabna
# 1. Location:  ['pabna', 'sathia', 'paba', 'rajshahi', 'boalmari']
# 2. DeathNo:  [0.0, 2.0, 3.0, 5.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['4:00pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['truck', 'motorbike', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 26 -- Separate road crashes kill two in Dhaka, another dies from electrocution
# 1. Location:  ['dohar', 'dhaka', 'keraniganj', 'nawabganj']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 27 -- Teenage boy killed in Feni road accident - Dhaka
# 1. Location:  ['feni', 'panchgachia', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 28 -- Bangladesh ranks 88th among 183 countries in road accident ...
# 1. Location:  ['asia']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 29 -- Roads blocked over deaths in road accidents
# 1. Location:  ['faridpur', 'kaliakair', 'chapainawabganj', 'gopalganj', 'bhanga', 'gazipur']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  []
# 4. Time:  ['2:30pm', '1:00pm', '7:00pm']
# 5. Daypart:  ['Evening', 'Afternoon']
# 6. Vehicle:  ['motorbike', 'bus', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 30 -- One killed in Barishal road accident - Dhaka
# 1. Location:  ['dhaka', 'gournadi']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['3:30pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['bike']
# 7. AccidentType: vehicle-human
#
#
# 31 -- How long before BRTA does its part?
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 33 -- Youth killed in road accident on Hanif Flyover
# 1. Location:  ['jatrabari']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['2:15pm', '4:00pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['motorcycle', 'motorbike']
# 7. AccidentType: vehicle-vehicle
#
#
# 34 -- Three killed in Natore road accident - Dhaka
# 1. Location:  ['singra', 'natore', 'dhaka', 'rajshahi']
# 2. DeathNo:  [3.0]
# 3. Injurred:  []
# 4. Time:  ['9:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 35 -- Three killed in Natore road accident - Dhaka
# 1. Location:  ['singra', 'natore', 'dhaka', 'rajshahi']
# 2. DeathNo:  [3.0]
# 3. Injurred:  []
# 4. Time:  ['9:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 36 -- Road crashes kill 3 children daily on average
# 1. Location:  []
# 2. DeathNo:  [7713.0, 34.0, 3.0, 1.0, 9.0, 19.0, 54.0, 119.0, 90.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 38 -- Experts for formulating ‘road safety act’ to prevent road crashes
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 39 -- Experts for formulating ‘road safety act’ to prevent road crashes
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 40 -- Chinese national dead, 2 wounded in Madaripur road crash
# 1. Location:  ['bachamara', 'madaripur', 'dhaka']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0, 3.0]
# 4. Time:  ['9am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 43 -- 3 college students die in Sirajganj road accident
# 1. Location:  ['sirajganj']
# 2. DeathNo:  [3.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 44 -- Two people killed, four injured in Munshiganj road accident
# 1. Location:  ['munshiganj', 'gazaria', 'titas']
# 2. DeathNo:  [4.0]
# 3. Injurred:  [4.0]
# 4. Time:  ['3:45am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 45 -- Man critically injured in car crash near Kalshi flyover
# 1. Location:  ['matikata']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['2:00pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['car']
# 7. AccidentType: vehicle-human
#
#
# 46 -- Blast in Dhaka, Bangladesh, kills 17 and injures over 100
# 1. Location:  ['dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 47 -- Blast in Dhaka, Bangladesh, kills 17 and injures over 100
# 1. Location:  ['dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 48 -- Deaths won’t stop as justice a mirage
# 1. Location:  []
# 2. DeathNo:  [48.0, 34.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 49 -- 3 killed, 5 injured in Bogura road accident - Dhaka
# 1. Location:  ['bogura', 'dhaka', 'nandigram']
# 2. DeathNo:  [3.0, 5.0]
# 3. Injurred:  [5.0]
# 4. Time:  ['8:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus', 'pickup', 'auto-rickshaw']
# 7. AccidentType: vehicle-vehicle
#
#
# 50 -- 3 killed, 5 injured in Bogura road accident - Dhaka
# 1. Location:  ['bogura', 'dhaka', 'nandigram']
# 2. DeathNo:  [3.0, 5.0]
# 3. Injurred:  [5.0]
# 4. Time:  ['8:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus', 'pickup', 'auto-rickshaw']
# 7. AccidentType: vehicle-vehicle
#
#
# 51 -- Traffic sergeant killed in Chattogram road accident
# 1. Location:  ['halishahar', 'chattogram']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['11:00pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['car']
# 7. AccidentType: vehicle-human
#
#
# 52 -- Traffic sergeant killed in Chattogram road accident
# 1. Location:  ['halishahar', 'chattogram']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['11:00pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['car']
# 7. AccidentType: vehicle-human
#
#
# 53 -- Motorcycle pillion rider killed in Dhaka road accident
# 1. Location:  ['shyampur', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['2:00am', '12:15am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['truck', 'bike', 'motorbike']
# 7. AccidentType: vehicle-vehicle
#
#
# 54 -- 17 dead, 25 injured in bus crash in Bangladesh| Gulf Times
# 1. Location:  []
# 2. DeathNo:  [17.0]
# 3. Injurred:  [25.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 55 -- At least 19 killed in Bangladesh bus accident
# 1. Location:  ['shibchar', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['8am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 56 -- 17 dead, 25 injured in bus crash in Bangladesh| Gulf Times
# 1. Location:  []
# 2. DeathNo:  [17.0]
# 3. Injurred:  [25.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 57 -- Motorcycle pillion rider killed in Dhaka road accident
# 1. Location:  ['shyampur', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['2:00am', '12:15am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['truck', 'bike', 'motorbike']
# 7. AccidentType: vehicle-vehicle
#
#
# 58 -- Care crisis behind high road crash deaths
# 1. Location:  ['shibpur', 'madaripur', 'durgapur', 'dhaka', 'chauddagram', 'kutubpur']
# 2. DeathNo:  [2001.0, 2.0, 3.0]
# 3. Injurred:  [17.0, 20.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 59 -- Two dead as bus crashes into power pole in Jhalakathi
# 1. Location:  ['rajapur', 'jhalakathi']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [13.0]
# 4. Time:  ['9 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 60 -- Jhenaidah road crash kills couple taking daughter to hospital
# 1. Location:  ['jhenaidah', 'kaliganj']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['6 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 61 -- Man killed in Kurigram road accident - Dhaka
# 1. Location:  ['dharmapur', 'phulbari', 'dhaka', 'kurigram', 'chandra']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['10:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['pickup']
# 7. AccidentType: vehicle-human
#
#
# 62 -- 20 umrah pilgrims killed, dozens hurt in Saudi Arabia road ...
# 1. Location:  []
# 2. DeathNo:  [35.0, 20.0]
# 3. Injurred:  [4.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 63 -- Bangladesh unlikely to achieve SDG set for road safety
# 1. Location:  ['madaripur']
# 2. DeathNo:  [2.0, 19.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 64 -- Mob torches 2 buses after motocyclist dies in Ashulia road accident
# 1. Location:  ['ashulia', 'dhaka']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  ['8 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 65 -- Bangabazar fire: Livelihoods burnt to ashes before Eid
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 66 -- Biggest Road Safety Project: Concern rising over fate of WB fund
# 1. Location:  []
# 2. DeathNo:  [19.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 67 -- 2 dead, 13 policemen injured in Sylhet road crash
# 1. Location:  ['sylhet']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [13.0]
# 4. Time:  ['10 pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['motorcycle', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 69 -- Will death haunt us again this Eid?
# 1. Location:  []
# 2. DeathNo:  [564.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 70 -- Will death haunt us again this Eid?
# 1. Location:  []
# 2. DeathNo:  [564.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 71 -- Three killed in Cox's Bazar road accident - Dhaka
# 1. Location:  ['dhaka', 'ramu']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  [1.0, 2.0]
# 4. Time:  ['7:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['auto-rickshaw', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 72 -- Will death haunt us again this Eid?
# 1. Location:  []
# 2. DeathNo:  [564.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 73 -- Road Crash, Casualties: Even BRTA, police figures don’t tally
# 1. Location:  []
# 2. DeathNo:  [263.0, 333.0, 303.0, 279.0, 636.0, 542.0]
# 3. Injurred:  [752.0, 420.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 74 -- Trader killed in Munshiganj road accident - Dhaka
# 1. Location:  ['munshiganj', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['6:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 75 -- Trader killed in Munshiganj road accident - Dhaka
# 1. Location:  ['munshiganj', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['6:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 76 -- Traffic movement resumes in New Market area
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['6:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 77 -- Two killed, 12 injured in Dinajpur road accident - Dhaka
# 1. Location:  ['govindapur', 'dhaka', 'dinajpur', 'birampur']
# 2. DeathNo:  [2.0, 12.0]
# 3. Injurred:  [12.0]
# 4. Time:  ['6:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['pickup', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 78 -- Another fire crushes traders’ Eid hopes
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['9:10am', '8:30am', '8:00pm', '6:00am', '5:15am', '2:00am', '5:40am', '9:40pm']
# 5. Daypart:  ['Night', 'Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 79 -- Madaripur road crash: Guardrail could’ve saved many lives
# 1. Location:  ['madaripur', 'shibchar']
# 2. DeathNo:  [264.0, 19.0]
# 3. Injurred:  [26.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 80 -- Promoting a culture of safety
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['truck', 'car', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 81 -- 12 motorcyclists killed in Bangladesh crashes on Eid day
# 1. Location:  ['faridpur', 'rajarhat', 'bhanga', 'dhaka', 'gazipur', 'rangpur', 'kurigram']
# 2. DeathNo:  [12.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 84 -- Why must Eid journeys be life-threatening?
# 1. Location:  ['munshiganj', 'natore', 'dinajpur']
# 2. DeathNo:  [1.0]
# 3. Injurred:  [688.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 85 -- Four killed, 2 injured in Tangail road accident
# 1. Location:  ['madhupur', 'dhanbari', 'baghil', 'mymensingh', 'tangail']
# 2. DeathNo:  [1.0, 2.0, 4.0]
# 3. Injurred:  [2.0, 4.0]
# 4. Time:  ['1:30pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['bus', 'auto-rickshaw']
# 7. AccidentType: vehicle-vehicle
#
#
# 86 -- Four killed, two injured in road accidents
# 1. Location:  ['khulna', 'adamdighi', 'debipur', 'mollahat', 'bogura', 'dhaka', 'bagerhat', 'feni', 'fakirhat']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['10:30am', '7:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['motorbike', 'bicycle', 'bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 87 -- 328 Killed in Bangladesh Road Crashes During Eid Festival Rush
# 1. Location:  []
# 2. DeathNo:  [328.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 89 -- 6 killed, 26 injured in road accidents in 4 dists
# 1. Location:  ['jashore', 'shailkupa', 'parbatipur', 'brahmapur', 'jhenaidah', 'dinajpur', 'dhaka', 'feni', 'kodalia', 'ruma']
# 2. DeathNo:  [2.0, 5.0, 6.0]
# 3. Injurred:  [2.0, 5.0, 6.0, 9.0, 20.0, 26.0]
# 4. Time:  ['7:30am', '8:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus', 'motorcycle', 'auto-rickshaw', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 91 -- Obaidul Quader unable to tackle roads, hardly visits ministry
# 1. Location:  ['madaripur', 'shibchar', 'chakaria']
# 2. DeathNo:  [6.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 92 -- Obaidul Quader unable to tackle roads, hardly visits ministry
# 1. Location:  ['madaripur', 'shibchar', 'chakaria']
# 2. DeathNo:  [6.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 93 -- Two workers killed, 12 injured in Satkhira road accident
# 1. Location:  ['kumira', 'satkhira', 'shariatpur', 'tala']
# 2. DeathNo:  [2.0, 13.0]
# 3. Injurred:  [3.0, 12.0, 13.0]
# 4. Time:  ['5:15am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 94 -- Two workers killed, 12 injured in Satkhira road accident
# 1. Location:  ['kumira', 'satkhira', 'shariatpur', 'tala']
# 2. DeathNo:  [2.0, 13.0]
# 3. Injurred:  [3.0, 12.0, 13.0]
# 4. Time:  ['5:15am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 95 -- Woman killed in Noakhali road accident | District
# 1. Location:  ['noakhali']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['rickshaw', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 96 -- 7 Bangladeshis named in Forbes Asia 30 Under 30 list
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 97 -- Two teenagers killed in Satkhira road accident
# 1. Location:  ['satkhira']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle', 'motorbike', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 98 -- College teacher killed in Bogura road accident - Dhaka
# 1. Location:  ['bogura', 'dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['10:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 99 -- College teacher killed in Bogura road accident
# 1. Location:  ['bogura']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['10:30 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 100 -- 2 college students die in Kushtia road accident | District
# 1. Location:  ['fultola', 'kushtia', 'khoksa']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 101 -- 2 college students die in Kushtia road accident | District
# 1. Location:  ['fultola', 'kushtia', 'khoksa']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 103 -- 2 killed in Cumilla road accident
# 1. Location:  ['daudkandi']
# 2. DeathNo:  [2.0, 4.0]
# 3. Injurred:  [4.0]
# 4. Time:  ['8:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 104 -- Minor boy killed in Bogura road accident - Dhaka
# 1. Location:  ['naogaon', 'bogura', 'dhaka', 'adamdighi']
# 2. DeathNo:  [10.0]
# 3. Injurred:  []
# 4. Time:  ['8:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 105 -- Boy dies after a flying rod from under-construction Dhaka expressway pierces his head
# 1. Location:  ['dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['10 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 106 -- 10 killed, dozens injured in Indian-controlled Kashmir road ...
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 107 -- Three people, including couple, killed in Feni road accident
# 1. Location:  ['feni', 'dighi']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  [2.0, 5.0]
# 4. Time:  ['2:30am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['pickup']
# 7. AccidentType: vehicle-human
#
#
# 108 -- Separate road accidents in Dhaka's Jatrabari leave two dead
# 1. Location:  ['jatrabari', 'dhaka']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  ['4:45 am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 109 -- 22 dead, 7 injured in road accident in Botswana
# 1. Location:  []
# 2. DeathNo:  [22.0]
# 3. Injurred:  [7.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 110 -- College student killed in Rajshahi road accident | District
# 1. Location:  ['paba', 'rajshahi']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['truck', 'motorbike']
# 7. AccidentType: vehicle-vehicle
#
#
# 111 -- 15 killed in central Canada road accident
# 1. Location:  []
# 2. DeathNo:  [15.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['truck', 'bus', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 112 -- 4 killed in Naogaon road accident
# 1. Location:  ['naogaon']
# 2. DeathNo:  [3.0, 4.0]
# 3. Injurred:  [3.0, 4.0]
# 4. Time:  ['1:15pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['rickshaw', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 113 -- Bangladesh, WB jointly launch project to improve road safety
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bike', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 114 -- New database for road traffic crashes in Dhaka under way
# 1. Location:  ['dhaka', 'ramna']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['Bus']
# 7. AccidentType: vehicle-human
#
#
# 115 -- New database for road traffic crashes in Dhaka under way
# 1. Location:  ['dhaka', 'ramna']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['Bus']
# 7. AccidentType: vehicle-human
#
#
# 116 -- Seven of a family, driver die in expressway ambulance crash
# 1. Location:  ['faridpur', 'bhanga']
# 2. DeathNo:  [7.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 117 -- 14 Killed and 12 Injured in a Crash in Bangladesh
# 1. Location:  ['surma', 'dhaka', 'sylhet']
# 2. DeathNo:  [13.0, 14.0]
# 3. Injurred:  [12.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 118 -- Unfit buses rule city streets
# 1. Location:  ['dhaka']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 119 -- 14 Killed and 12 Injured in a Crash in Bangladesh
# 1. Location:  ['surma', 'dhaka', 'sylhet']
# 2. DeathNo:  [13.0, 14.0]
# 3. Injurred:  [12.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 120 -- Fatality high with passengers on goods vehicles
# 1. Location:  ['mouchak', 'bahubal', 'surma', 'dhaka', 'habiganj', 'kutubpur', 'sylhet']
# 2. DeathNo:  [3.0, 36.0, 453.0]
# 3. Injurred:  [10.0, 15.0]
# 4. Time:  ['4:30pm', '5:30am']
# 5. Daypart:  ['Morning', 'Afternoon']
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 121 -- Road widening project claims 1009 trees
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 122 -- 1 BGB member dies, 6 hurt in Gazipur road crash
# 1. Location:  ['rajendrapur', 'gazipur']
# 2. DeathNo:  [1.0, 6.0]
# 3. Injurred:  [6.0]
# 4. Time:  ['6:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 123 -- Mother, son among 3 killed in Sirajganj road accident | District
# 1. Location:  ['sirajganj', 'nalka', 'hatikumrul']
# 2. DeathNo:  [3.0, 5.0]
# 3. Injurred:  [3.0, 5.0]
# 4. Time:  ['7:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['rickshaw', 'auto-rickshaw', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 124 -- Road crash kills 9, injures 31 in S. Afghanistan | News
# 1. Location:  []
# 2. DeathNo:  [24.0, 9.0]
# 3. Injurred:  [9.0, 2.0, 15.0, 31.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 125 -- Fatality high with passengers on goods vehicles
# 1. Location:  ['mouchak', 'bahubal', 'surma', 'dhaka', 'habiganj', 'kutubpur', 'sylhet']
# 2. DeathNo:  [3.0, 36.0, 453.0]
# 3. Injurred:  [10.0, 15.0]
# 4. Time:  ['4:30pm', '5:30am']
# 5. Daypart:  ['Morning', 'Afternoon']
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 126 -- Two killed in Khagrachari road accident | District
# 1. Location:  ['manikchari']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  ['8 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['rickshaw']
# 7. AccidentType: vehicle-human
#
#
# 127 -- Bangabandhu Bridge toll collection: 180 million taka in 6 days
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 128 -- Bangabandhu Bridge toll collection: 180 million taka in 6 days
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 129 -- Separate road accidents kill 4 in Bangladesh
# 1. Location:  ['gaibandha', 'dhaka', 'rangpur', 'gobindaganj']
# 2. DeathNo:  [2.0, 4.0]
# 3. Injurred:  []
# 4. Time:  ['7 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 130 -- 468 killed in road accidents in May: report
# 1. Location:  ['dhaka', 'sylhet', 'chattogram']
# 2. DeathNo:  [43.0, 110.0, 16.0, 468.0, 181.0, 28.0]
# 3. Injurred:  [3.0, 43.0, 16.0, 114.0, 50.0, 151.0, 62.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 131 -- 20 injured in Naogaon road accident | District
# 1. Location:  ['naogaon', 'rajshahi']
# 2. DeathNo:  []
# 3. Injurred:  [20.0, 4.0]
# 4. Time:  ['7pm']
# 5. Daypart:  ['Evening']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 132 -- DPDC employee among 2 killed in Dhaka road accident
# 1. Location:  ['dhaka']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  ['10:00am', '2:30am']
# 5. Daypart:  ['Night', 'Morning']
# 6. Vehicle:  ['motorcycle', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 133 -- Dozens killed in horrific Kenya road crash | News
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  [30.0]
# 4. Time:  ['6:30 pm']
# 5. Daypart:  ['Evening']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 134 -- 3 dead in Syhlet road accident
# 1. Location:  ['sylhet', 'osmaninagar']
# 2. DeathNo:  [3.0, 15.0]
# 3. Injurred:  [10.0, 3.0]
# 4. Time:  ['4:30am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 135 -- One killed in Gopalganj road accident | District
# 1. Location:  ['jashore', 'gopalganj', 'maheshpur', 'kashiani']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['7am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 136 -- Two people killed in Munshiganj road accident - Dhaka
# 1. Location:  ['munshiganj', 'dhaka', 'srinagar']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  [2.0, 3.0]
# 4. Time:  ['9:30 pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 137 -- Two people killed in Munshiganj road accident - Dhaka
# 1. Location:  ['munshiganj', 'dhaka', 'srinagar']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  [2.0, 3.0]
# 4. Time:  ['9:30 pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 138 -- 2 schoolboys killed in Meherpur motorcycle crash on Eid day
# 1. Location:  ['darbeshpur', 'chuadanga', 'meherpur']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  ['3pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['motorcycle']
# 7. AccidentType: vehicle-human
#
#
# 139 -- Two people killed in Gazipur road accident - Dhaka
# 1. Location:  ['kaliakair', 'dhaka', 'gazipur']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['6:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['auto-rickshaw', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 140 -- Two killed in road accident on Bogura-Rangpur highway
# 1. Location:  ['bogura', 'gobindaganj', 'shibganj']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['6:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 141 -- Two killed in road accident on Bogura-Rangpur highway
# 1. Location:  ['bogura', 'gobindaganj', 'shibganj']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['6:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 143 -- Animal Market causes 4 road closure in Tongi
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 145 -- Waste pile fire at Matarbari Thermal Power Plant raging for hours
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['12pm', '7:30pm']
# 5. Daypart:  ['Evening', 'Afternoon']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 146 -- Death toll rises to 29 in Mexico bus plunge | News
# 1. Location:  []
# 2. DeathNo:  [2.0, 13.0, 29.0]
# 3. Injurred:  [27.0, 8.0, 19.0, 6.0]
# 4. Time:  []
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['bus', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 147 -- Five killed in Sylhet road accident | News
# 1. Location:  ['jaintapur', 'sylhet']
# 2. DeathNo:  [2.0, 5.0, 2023.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['10pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['auto-rickshaw', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 149 -- 299 people killed in road accidents during Eid-ul-Azha journey
# 1. Location:  ['dhaka']
# 2. DeathNo:  [25.0, 299.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorbike', 'pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 150 -- Four killed in Gopalganj road accident | News
# 1. Location:  ['gopalganj']
# 2. DeathNo:  [4.0, 7.0]
# 3. Injurred:  [4.0, 7.0]
# 4. Time:  ['7:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck']
# 7. AccidentType: vehicle-human
#
#
# 151 -- People reluctant to follow the rules, deaths on the rise
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['00 am', '2:30 pm', '11:00 am']
# 5. Daypart:  ['Night', 'Morning', 'Afternoon']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 152 -- No rain, yet upstream water enters village
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 153 -- 2 killed in bus-CNG collision in Tangail
# 1. Location:  ['tangail']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 154 -- 2 killed in Tangail road accident
# 1. Location:  ['dhanbari', 'tangail']
# 2. DeathNo:  [2.0, 4.0]
# 3. Injurred:  [4.0]
# 4. Time:  ['7:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['auto-rickshaw', 'bus']
# 7. AccidentType: vehicle-vehicle
#
#
# 155 -- 10 Home Ministry's officials, employees transferred
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 156 -- 1 killed in road accident in Khulna
# 1. Location:  ['khulna']
# 2. DeathNo:  [1.0]
# 3. Injurred:  []
# 4. Time:  ['1 pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['bike']
# 7. AccidentType: vehicle-human
#
#
# 157 -- Mother, son among 5 killed in Bogura road crashes
# 1. Location:  ['adamdighi', 'murail', 'shajahanpur', 'shahjahanpur', 'bogura', 'katabaria']
# 2. DeathNo:  [3.0, 5.0]
# 3. Injurred:  [3.0]
# 4. Time:  ['3:30am', '8pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['motorbike', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 158 -- 95% of Ctg crash deaths caused by risky road users: Study
# 1. Location:  ['chattogram']
# 2. DeathNo:  [95.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['car']
# 7. AccidentType: vehicle-human
#
#
# 159 -- Five lives lost in road accidents
# 1. Location:  ['khulna', 'kushtia', 'chuadanga', 'darshana', 'narayanganj', 'bandar']
# 2. DeathNo:  [2.0, 3.0]
# 3. Injurred:  []
# 4. Time:  ['11:30am', '3:00pm']
# 5. Daypart:  ['Morning', 'Afternoon']
# 6. Vehicle:  ['motorbike', 'bike', 'car', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 160 -- Momen seeks further ICRC Cross cooperation on Rohingya ...
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 161 -- 10 killed in road accidents
# 1. Location:  ['ishwardi', 'muladuli', 'adamdighi', 'murail', 'konabari', 'amtali', 'pabna', 'bogura', 'dhaka', 'iswardi', 'gazipur', 'natore', 'chattogram', 'rajshahi', 'banshkhali']
# 2. DeathNo:  [1.0, 2.0, 3.0, 4.0, 10.0, 12.0]
# 3. Injurred:  [2.0, 3.0, 4.0, 12.0, 19.0]
# 4. Time:  ['2:00pm', '9:30am', '3:00am', '11:00am']
# 5. Daypart:  ['Night', 'Morning', 'Afternoon']
# 6. Vehicle:  ['pickup', 'bus', 'car', 'truck', 'auto-rickshaw']
# 7. AccidentType: vehicle-vehicle
#
#
# 162 -- Road accident kills two students in Panchagarh | District
# 1. Location:  ['debiganj', 'panchagarh']
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 163 -- Gautam Adani calls on PM Hasina over Godda plant handover
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 164 -- The toll for the Bangabandhu Tunnel ranges from 200 taka to ...
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 165 -- PM stresses master plan for better sewage management up to ...
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 166 -- 324 killed in road accidents during Eid-ul-Azha: Road Safety Foundation
# 1. Location:  []
# 2. DeathNo:  [106.0, 324.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 167 -- Four drown in Kurigram, Rajshahi
# 1. Location:  ['durgapur', 'rajshahi']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['10:30am', '8:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 168 -- Army corporal among 2 killed in separate road crashes in Dinajpur
# 1. Location:  ['chirirbandar', 'dinajpur', 'parbatipur']
# 2. DeathNo:  [2.0, 10.0]
# 3. Injurred:  [10.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['truck', 'bus', 'motorbike']
# 7. AccidentType: vehicle-vehicle
#
#
# 172 -- Latest Financial News, Finance News today in Bangladesh
# 1. Location:  []
# 2. DeathNo:  [1.0]
# 3. Injurred:  [12.0]
# 4. Time:  ['4:00 am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 173 -- 5 killed in Sylhet road accident
# 1. Location:  ['sylhet']
# 2. DeathNo:  [5.0]
# 3. Injurred:  [3.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['car']
# 7. AccidentType: vehicle-human
#
#
# 174 -- Are our roads friendly towards women, children?
# 1. Location:  ['jatrabari']
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus', 'motorbike']
# 7. AccidentType: vehicle-vehicle
#
#
# 175 -- Road Accidents: Casualties keep mounting for indiscipline
# 1. Location:  ['bhandaria', 'kanchan', 'pirojpur', 'jhalakathi']
# 2. DeathNo:  [17.0]
# 3. Injurred:  [35.0]
# 4. Time:  ['10:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 176 -- Bus overturns again on expressway, supervisor killed
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 177 -- Road accident in Bangladesh kills 17 people
# 1. Location:  ['bhandaria', 'dhaka', 'jhalakathi']
# 2. DeathNo:  [17.0]
# 3. Injurred:  []
# 4. Time:  ['04:57 pm', '04:51 pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 179 -- 350-year-old Dhaka Gate under renovation
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 180 -- Why are human rights defenders being targeted?
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 182 -- Four killed, 5 injured in road accidents
# 1. Location:  ['faridpur', 'gopalpur', 'ghatail', 'bhanga', 'gazipur', 'chattogram', 'sitakunda', 'fouzdarhat', 'tangail']
# 2. DeathNo:  [2.0, 4.0, 5.0]
# 3. Injurred:  [2.0, 3.0, 4.0, 5.0]
# 4. Time:  ['12:45 pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 183 -- A long stride for rail connectivity
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['train']
# 7. AccidentType: vehicle-human
#
#
# 184 -- N'ganj garments factory fire: Fire truck driver suffers heart attack, crashes into pedestrian, leaving both dead
# 1. Location:  ['narayanganj', 'dhaka']
# 2. DeathNo:  [3.0]
# 3. Injurred:  []
# 4. Time:  ['10:30am', '11:30am', '11am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['bus', 'auto-rickshaw', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 185 -- Fire service truck driver dies of stroke behind the wheel ...
# 1. Location:  ['narayanganj', 'khulna', 'dhaka']
# 2. DeathNo:  [1.0, 2.0, 39.0, 8.0, 9.0]
# 3. Injurred:  [8.0, 2.0]
# 4. Time:  ['10:30 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['rickshaw', 'car', 'bus', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 186 -- Siblings crushed by bus on Bhanga Express Highway
# 1. Location:  ['faridpur', 'meherpur', 'darbeshpur', 'bhanga', 'dhaka']
# 2. DeathNo:  [2.0, 3.0, 7.0]
# 3. Injurred:  [16.0]
# 4. Time:  ['3:00 pm']
# 5. Daypart:  ['Afternoon']
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 187 -- Ambulance owners call off strike
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  ['00 am']
# 5. Daypart:  ['Night']
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 188 -- Bangladesh-Japan relations on the right track
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['Honda']
# 7. AccidentType: vehicle-human
#
#
# 189 -- It’s not EC’s job to ensure voter turnout
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 190 -- 2 die as truck-car collide in Mirsarai | District
# 1. Location:  ['kumira']
# 2. DeathNo:  [2.0, 3.0, 6.0]
# 3. Injurred:  [2.0, 3.0, 6.0]
# 4. Time:  ['6 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 191 -- Two killed in Naogaon road accident | District
# 1. Location:  ['naogaon', 'patnitala', 'chandra']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0, 3.0]
# 4. Time:  ['5:30am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['pickup']
# 7. AccidentType: vehicle-human
#
#
# 192 -- Six killed in road accidents in districts
# 1. Location:  ['patnitala', 'jashore', 'keshabpur', 'naogaon', 'chattogram', 'chandra']
# 2. DeathNo:  [2.0, 6.0]
# 3. Injurred:  [2.0, 3.0, 6.0]
# 4. Time:  ['8:00pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['motorbike', 'pickup', 'truck']
# 7. AccidentType: vehicle-vehicle
#
#
# 193 -- Two dead, 3 hurt in road crash as driver falls asleep
# 1. Location:  ['patnitala', 'kumira', 'naogaon', 'dinajpur', 'nawabganj']
# 2. DeathNo:  [2.0]
# 3. Injurred:  [2.0]
# 4. Time:  ['6:30am', '6:00am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['rickshaw', 'truck', 'motorcycle', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 194 -- 1 killed, 1 injured in car accident on Mawa Expressway
# 1. Location:  ['munshiganj', 'dhaka', 'sreenagar']
# 2. DeathNo:  [1.0]
# 3. Injurred:  [1.0]
# 4. Time:  ['9 am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['car']
# 7. AccidentType: vehicle-human
#
#
# 195 -- Vehicle insurance business going thru tough times
# 1. Location:  []
# 2. DeathNo:  []
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['motorcycle', 'car']
# 7. AccidentType: vehicle-vehicle
#
#
# 196 -- Motorcyclist killed in Satkhira road accident
# 1. Location:  ['satkhira', 'kalaroa']
# 2. DeathNo:  [8.0]
# 3. Injurred:  []
# 4. Time:  ['8am']
# 5. Daypart:  ['Morning']
# 6. Vehicle:  ['truck', 'motorcycle']
# 7. AccidentType: vehicle-vehicle
#
#
# 197 -- Road Safety Movement 2018: Infrastructure improves, safety worsens
# 1. Location:  []
# 2. DeathNo:  [2.0]
# 3. Injurred:  []
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  ['bus']
# 7. AccidentType: vehicle-human
#
#
# 198 -- 6 killed, 20 injured as 2 buses collide in India's Maharashtra
# 1. Location:  []
# 2. DeathNo:  [6.0]
# 3. Injurred:  [20.0]
# 4. Time:  []
# 5. Daypart:  []
# 6. Vehicle:  []
# 7. AccidentType: N/A
#
#
# 199 -- Three bikers killed in Kurigram road accident
# 1. Location:  ['kurigram', 'nageshwari']
# 2. DeathNo:  [3.0]
# 3. Injurred:  []
# 4. Time:  ['9:30pm']
# 5. Daypart:  ['Night']
# 6. Vehicle:  ['bike', 'bus', 'motorcycle']
# 7. AccidentType: vehicle-vehicle

# %%
len(injuredNumber)   #deathNumber
# Out:
# 19

# %%
news_feature = pd.DataFrame(
    {'Date': newsDate, 'Location': accidentLocation,'Death Number': deathNumber,
     'Injured Number': injuredNumber,'Accident Time':  accTime, 'Part of Day': dayPart,
     'Accident Vechile': vechileList, 'Accident Type': acciddentType,
     'News Text': newsText, 'News Link': newsUrl
    })

news_feature
# Out:
#            Date                                      Location  \
# 0    2022-08-16  [uttara, islampur, dhaka, gazipur, jamalpur]
# 1    2022-09-15                          [palash, chattogram]
# 2    2022-10-08                                            []
# 3    2022-10-26                                            []
# 4    2022-10-27                   [narail, dhaka, tularampur]
# ..          ...                                           ...
# 173  2023-07-28                                            []
# 174  2023-07-28                           [satkhira, kalaroa]
# 175  2023-07-28                                            []
# 176  2023-07-29                                            []
# 177  2023-07-29                        [kurigram, nageshwari]
#
#                 Death Number Injured Number Accident Time  Part of Day  \
# 0    [2.0, 12.0, 70.0, 15.0]    [3.0, 12.0]      [4:00pm]  [Afternoon]
# 1                [10.0, 4.0]    [10.0, 2.0]      [1:30am]      [Night]
# 2                     [11.0]             []      [5:15am]    [Morning]
# 3                      [2.0]             []            []           []
# 4                          1             []      [8:00am]    [Morning]
# ..                       ...            ...           ...          ...
# 173                        1             []            []           []
# 174                    [8.0]             []         [8am]    [Morning]
# 175                    [2.0]             []            []           []
# 176                    [6.0]         [20.0]            []           []
# 177                    [3.0]             []      [9:30pm]      [Night]
#
#             Accident Vechile    Accident Type  \
# 0            [Bus, bus, car]  vehicle-vehicle
# 1                      [bus]    vehicle-human
# 2               [bus, truck]  vehicle-vehicle
# 3                      [bus]    vehicle-human
# 4          [car, motorcycle]  vehicle-vehicle
# ..                       ...              ...
# 173        [motorcycle, car]  vehicle-vehicle
# 174      [truck, motorcycle]  vehicle-vehicle
# 175                    [bus]    vehicle-human
# 176                       []              N/A
# 177  [bike, bus, motorcycle]  vehicle-vehicle
#
#                                              News Text  \
# 0    Crane drops heavy girder on car in Uttara; new...
# 1    Four people were killed and 10 others, includi...
# 2    This undated UNB photo shows the debris of a c...
# 3    Road traffic injuries (RTIs) are among the lea...
# 4    A youth has been killed on Thursday in a road ...
# ..                                                 ...
# 173  People not interested amid absence of legal ob...
# 174  A motorcyclist was killed in a road accident o...
# 175  Roads still unsafe despite infrastructure deve...
# 176
# 177  Three motorcycle riders were killed when a bus...
#
#                                              News Link
# 0    https://www.thedailystar.net/news/bangladesh/a...
# 1    https://www.tbsnews.net/bangladesh/4-killed-10...
# 2    https://www.newagebd.net/article/183133/11-peo...
# 3    https://www.thedailystar.net/opinion/views/new...
# 4    https://www.newagebd.net/article/184806/youth-...
# ..                                                 ...
# 173  https://www.thedailystar.net/business/economy/...
# 174  https://bangladeshpost.net/posts/motorcyclist-...
# 175  https://www.thedailystar.net/news/bangladesh/a...
# 176  https://www.daily-bangladesh.com/english/inter...
# 177  https://www.thedailystar.net/news/bangladesh/a...
#
# [178 rows x 10 columns]

# %%
news_feature.to_csv('news_feature.csv', sep=',', index=False, encoding='utf-8')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
news_feature.to_csv('/content/gdrive/My Drive/news_feature.csv', index=False, encoding='utf-8')
# Out:
# Mounted at /content/gdrive

# %%
AccicdentLoc, NERloc= find_accident_loc(related_text, textWithTitle)
print(AccicdentLoc)
print(NERloc)
#age= find_age(clearText)
#print(age)
# Out:
# ['sreepur', 'magura', 'faridpur', 'daulatpur', 'khulna']
# [Magura, Khulna city, Chalna, Khulna, Khulna, Magura, Parchalna, Khulna, Magura, Parchalna]

# %%
#related_text.append(news['title'][i]) #title is needed to find death/injure number
death_num, injure_num= find_death_injure_number(related_text)
if len(death_num)==0:
  death_num.aeppen(1)
print(death_num)
print(injure_num)
# Out:
# death:  [2, 3]
# inj:  []
# [2, 3]
# []

# %%
time, partOfDay= find_time_of_accident(article.text)
print(time)
print(partOfDay)
# Out:
# time from ner- ['11:00am', '9:00am', 'morning']
# ['9:00am', '11:00am']
# ['Morning']

# %%
extracted_vehicles = extract_vehicles(article.text)
print(list(set(extracted_vehicles)))
# Out:
# ['motorcycle']

# %% [markdown]
# ***NOT required-- for testing ***
